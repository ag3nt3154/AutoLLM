# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Text Classification

# %%
import logging

# Configure the logging settings
logging.basicConfig(
    # level=logging.INFO,  # Set the minimum log level to DEBUG
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',  # Define the log format
    handlers=[
        logging.FileHandler('app.log'),  # Log to a file
        logging.StreamHandler()  # Log to the console
    ]
)

# Create a logger
logger = logging.getLogger('my_app')

# %% [markdown]
# # Kaggle E-commerce Dataset

# %%
import pandas as pd
import logging

df_data = pd.read_pickle('./data/Ecommerce/ecommerce_classification_dataset.pkl')
possible_labels = list(df_data['label'].unique())
df_data
# Out:
#              label                                               text
# 0        Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1        Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2        Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3        Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4        Household  Incredible Gifts India Wooden Happy Birthday U...
# ...            ...                                                ...
# 50420  Electronics  Strontium MicroSD Class 10 8GB Memory Card (Bl...
# 50421  Electronics  CrossBeats Wave Waterproof Bluetooth Wireless ...
# 50422  Electronics  Karbonn Titanium Wind W4 (White) Karbonn Titan...
# 50423  Electronics  Samsung Guru FM Plus (SM-B110E/D, Black) Colou...
# 50424  Electronics                   Micromax Canvas Win W121 (White)
#
# [50425 rows x 2 columns]

# %% [markdown]
# ## Train - test split

# %%
from AutoLLM.utils.helpers import split_dataframe

df_train, df_test = split_dataframe(df_data, 100 / df_data.shape[0], 42, 'label')
display(df_test)
display(df_train)
# Out:
#                         label  \
# 32109  Clothing & Accessories
# 21746                   Books
# 1214                Household
# 25733                   Books
# 43918             Electronics
# ...                       ...
# 24703                   Books
# 13919               Household
# 24624                   Books
# 49880             Electronics
# 172                 Household
#
#                                                     text
# 32109  Rovars Unisex All-in-1 Suit Planning a trip to...
# 21746  Wiley's Physical Chemistry For JEE (Main & Adv...
# 1214   Ebee Store Shoe Rack with 5 Shelves (Maroon) G...
# 25733  Strauss Bronx YB Skateboard Skateboard is a ty...
# 43918  Cables Kart™ Digital to Analogue Optical Audio...
# ...                                                  ...
# 24703  New Saraswati Health and Physical Education Cl...
# 13919  FRESHWORLD Plastic Vacuum Sealer with Starter ...
# 24624                      Current Affairs Yearly  2019
# 49880  IKALL K16 1.8-inch Mobile(White) Colour:White ...
# 172    Beadsnfashion Jewellery Making German Silver R...
#
# [100 rows x 2 columns]
#              label                                               text
# 30368        Books  I Am Malala: The Girl Who Stood Up for Educati...
# 15227    Household  IFB 5.5 kg Dryer (Turbo Dry EX, Silver) Color:...
# 42493  Electronics  Skullcandy JIB S2DUDZ-003 In-Ear Headphone (Bl...
# 30360        Books  I Am Malala: The Girl Who Stood Up for Educati...
# 43558  Electronics  DELL Inspiron 3464, 2017 24 "All-In-One i5 7th...
# ...            ...                                                ...
# 44072  Electronics  ULTIMA Invisible Cable Aluminium Universal Adj...
# 8258     Household  Aventure Shoe Rack Free Standing,Cube Organize...
# 46864  Electronics  Fujifilm X Series GFX 50S 51.4MP Mirrorless Me...
# 49032  Electronics  Ceuta Retails, Car Cradle for Cell Phones - Un...
# 25044        Books  The Everything Kids' Learning French Book: Fun...
#
# [50325 rows x 2 columns]

# %% [markdown]
# # Classifer

# %% [markdown]
# ## Build classifier agent

# %%
from pydantic import BaseModel
from typing import Literal
from AutoLLM.interfaces.api_client import APIClient
from config import API_KEY
from AutoLLM.prompts.classifier import classifier_template
from AutoLLM.modules.base_agent import BaseAgent
import json
from tqdm.notebook import tqdm
from sklearn.metrics import accuracy_score

url = "https://api.studio.nebius.ai/v1/"

classifier_client = APIClient(url=url, api_key=API_KEY, model="meta-llama/Llama-3.2-3B-Instruct")
classifier_gen_config = {
    "temperature": 1e-10,
    "top_p": 1e-10,
    # "top_k": 1,
}
classifier_client.load_generation_config(classifier_gen_config)

class classifier_schema(BaseModel):
    label: str

class ClassifierAgent(BaseAgent):
    def __init__(self, client, json_schema, gen_config):
        super().__init__(client, json_schema, gen_config)
        self.template = classifier_template
        self.guide = '{"label": '
        self.output_format = f"""label: (Literal) Return one of the choices from the following list: {possible_labels}."""
        self.system_message = "You are a helpful AI assistant."
        self.instructions = ""
        self.X = None
        self.y_true = None
    
    def _generate_prompt(self, **kwargs):
        if not self.instructions:
            if 'instructions' in kwargs:
                self.instructions = kwargs['instructions']
            else:
                raise ValueError("Instructions not set.")

        self.user_prompt = self.template.format(
            instructions=self.instructions,
            output_format=self.output_format,
            input=kwargs['input']
        )
        messages = [
            {"role": "system", "content": self.system_message},
            {"role": "user", "content": self.user_prompt},
            {"role": "assistant", "content": self.guide},
        ]
        return messages
    
    def _parse_response(self, response):
        return json.loads(response)['label']

    def run_samples(self, X):
        y_pred = []
        for input in tqdm(X):
            label = self.run(input=input)
            y_pred.append(label)
        return y_pred
    
    def evaluate_accuracy(self, X=None, y_true=None):
        if X is None or y_true is None:
            X = self.X
            y_true = self.y_true
        y_pred = self.run_samples(X)
        return accuracy_score(y_true, y_pred)
    
    def load_data(self, X, y_true):
        self.X = X
        self.y_true = y_true

# %% [markdown]
# ## Test classifier agent

# %%
initial_instruction = f"Based on the given input item description, label the item as one of the following: {possible_labels}."

ca = ClassifierAgent(classifier_client, classifier_sc
                     hema, classifier_gen_config)
ca.instructions = initial_instruction
print(ca.run_samples(df_test['text'].to_list()))
print(ca.evaluate_accuracy(
    X=df_test['text'],
    y_true=df_test['label']
))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2025-02-06 15:04:33,604 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:33,995 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:34,377 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:34,762 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:35,207 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:35,664 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:36,055 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:36,445 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:36,883 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:37,258 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:37,674 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:38,124 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:38,508 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:38,891 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:39,306 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:39,690 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:40,168 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:40,572 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:40,975 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:41,377 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:41,755 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:42,154 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:42,636 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:43,139 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:43,522 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:43,965 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:44,359 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:45,235 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:45,806 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:46,885 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:47,441 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:47,842 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:48,237 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:49,385 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:49,763 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:50,135 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:50,639 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:51,124 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:51,489 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:51,877 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:52,355 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:52,969 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:53,334 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:53,718 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:54,094 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:54,467 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:54,863 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:55,325 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:55,717 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:56,083 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:56,550 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:56,929 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:57,316 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:57,782 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:58,158 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:58,533 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:58,999 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:59,414 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:04:59,799 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:00,185 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:00,572 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:00,955 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:01,344 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:01,715 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:02,182 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:02,565 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:02,947 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:03,414 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:03,822 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:04,230 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:04,614 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:05,014 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:05,418 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:05,864 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:06,280 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:06,661 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:07,397 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:07,813 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:08,194 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:08,600 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:09,046 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:09,453 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:09,968 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:10,472 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:10,861 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:11,278 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:11,663 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:12,045 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:12,648 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:13,143 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:13,544 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:13,927 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:14,678 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:15,080 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:15,477 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:16,420 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:16,827 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:17,208 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:17,576 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:18,066 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# ['Clothing & Accessories', 'Books', 'Household', 'Electronics', 'Electronics', 'Household', 'Household', 'Books', 'Books', 'Clothing & Accessories', 'Household', 'Clothing & Accessories', 'Household', 'Household', 'Clothing & Accessories', 'Household', 'Household', 'Clothing & Accessories', 'Clothing & Accessories', 'Electronics', 'Books', 'Household', 'Household', 'Electronics', 'Household', 'Household', 'Household', 'Household', 'Books', 'Books', 'Books', 'Household', 'Household', 'Books', 'Electronics', 'Books', 'Household', 'Household', 'Books', 'Books', 'Household', 'Household', 'Electronics', 'Household', 'Household', 'Household', 'Household', 'Household', 'Electronics', 'Books', 'Household', 'Electronics', 'Electronics', 'Electronics', 'Electronics', 'Books', 'Books', 'Clothing & Accessories', 'Books', 'Household', 'Electronics', 'Books', 'Clothing & Accessories', 'Clothing & Accessories', 'Household', 'Electronics', 'Household', 'Household', 'Household', 'Clothing & Accessories', 'Electronics', 'Household', 'Household', 'Clothing & Accessories', 'Household', 'Electronics', 'Household', 'Household', 'Books', 'Clothing & Accessories', 'Household', 'Clothing & Accessories', 'Household', 'Clothing & Accessories', 'Household', 'Clothing & Accessories', 'Household', 'Household', 'Electronics', 'Clothing & Accessories', 'Household', 'Household', 'Household', 'Clothing & Accessories', 'Electronics', 'Books', 'Household', 'Household', 'Electronics', 'Household']
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2025-02-06 15:05:18,565 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:19,079 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:19,469 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:19,846 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:20,244 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:20,629 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:20,993 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:22,355 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:22,750 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:23,141 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:23,527 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:23,996 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:24,378 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:24,815 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:25,208 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:25,600 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:25,990 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:26,388 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:26,792 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:27,174 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:27,539 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:27,944 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:28,325 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:28,706 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:29,117 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:29,507 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:29,898 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:30,288 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:30,659 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:31,054 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:31,422 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:31,879 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:32,270 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:32,645 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:33,121 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:33,497 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:33,884 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:34,254 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:34,636 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:35,017 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:35,465 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:35,837 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:36,386 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:36,903 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:37,308 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:37,701 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:38,536 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:38,919 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:39,307 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:39,669 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:40,380 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:40,769 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:41,187 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:41,611 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:42,532 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:42,905 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:43,271 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:43,682 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:44,050 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:44,434 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:44,821 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:45,300 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:45,684 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:46,103 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:46,478 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:46,866 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:47,733 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:48,111 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:48,499 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:48,983 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:49,361 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:49,745 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:50,615 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:51,133 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:51,515 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:51,897 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:52,355 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:52,914 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:53,385 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:53,780 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:54,147 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:54,614 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:54,992 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:55,384 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:55,843 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:56,351 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:56,808 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:57,196 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:57,687 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:58,083 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:58,479 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:58,866 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:59,313 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:05:59,712 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:06:00,095 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:06:00,476 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:06:00,851 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:06:01,230 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:06:01,609 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 15:06:02,077 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 0.79

# %% [markdown]
# # Optimize prompt

# %%
from AutoLLM.modules.mutation_agent import MutationAgent
from AutoLLM.modules.critic_agent import CriticAgent
from AutoLLM.modules.refine_agent import RefineAgent
from AutoLLM.modules.expert_agent import ExpertAgent

meta_client = APIClient(url=url, api_key=API_KEY, model="Qwen/Qwen2.5-32B-Instruct")
meta_generation_config = {
    "temperature": 0.7,
    "top_p": 0.9,
}


class OptimusPrompt:
    def __init__(
        self,
        task_description,
        initial_instruction,
        meta_client,
        meta_generation_config,
        num_mutation_variations=10,
        num_refine_variations=5,
    ):
        self.task_description = task_description
        self.initial_instruction = initial_instruction
        self.instruction_population = []
        
        self.num_mutation_variations = num_mutation_variations
        self.num_refine_variations = num_refine_variations
        self.instruction_cache = [self.initial_instruction]
        self.meta_client = meta_client
        self.meta_generation_config = meta_generation_config
        
    
    def mutate(self, seed_instruction):
        self.mutation_agent = MutationAgent(self.meta_client, self.meta_generation_config)
        mutations = self.mutation_agent.run(
            task_description=self.task_description,
            num_variations=self.num_mutation_variations,
            seed_instruction=seed_instruction,
        )
        return mutations
    
    def score_cache(self, eval_func):
        for instruction in self.instruction_cache:
            score = eval_func(instruction)
            self.instruction_population.append((instruction, score))
        self.instruction_cache = []
    
    def select_top_k_instructions(self, k):
        self.instruction_population.sort(key=lambda x: x[1], reverse=True)
        return [instruction for instruction, _ in self.instruction_population[:k]]
    
    def build_wrong_example_text(self, wrong_examples):
        wrong_examples_text = []
        for text, label_true, label_pred in wrong_examples:
            wrong_examples_text.append(f"""
        [Text]:               {text}
        [Correct Label]:      {label_true}
        [Predicted Label]:    {label_pred}""")
        return "\n".join(wrong_examples_text)
    
    def critique(self, seed_instruction, wrong_example_text):
        self.critic_agent = CriticAgent(self.meta_client, self.meta_generation_config)
        critique = self.critic_agent.run(
            task_description=self.task_description,
            seed_instruction=seed_instruction,
            wrong_examples=wrong_example_text,
        )
        return critique
    
    def build_wrong_example_with_critique_text(self, wrong_examples, critique):
        wrong_examples_with_critique = []
        for i in range(len(wrong_examples)):
            
            wrong_examples_with_critique.append(f"""
                [Text]:               {wrong_examples[i][0]}
                [Correct Label]:      {wrong_examples[i][1]}
                [Predicted Label]:    {wrong_examples[i][2]}
                [Critique]:           {critique[i]}""")
        return "\n".join(wrong_examples_with_critique)
            

    def refine(self, seed_instruction, wrong_examples_with_critique):
        self.refine_agent = RefineAgent(self.meta_client, self.meta_generation_config)
        refined_instructions = self.refine_agent.run(
            task_description=self.task_description,
            instruction=seed_instruction,
            examples=wrong_examples_with_critique,
            num_variations=self.num_refine_variations,
        )
        return refined_instructions
        
    def get_expert(self, seed_instruction):
        self.expert_agent = ExpertAgent(self.meta_client, self.meta_generation_config)
        expert = self.expert_agent.run(
            instruction=seed_instruction,
        )
        return expert

# %% [markdown]
# # Optimization loop

# %%
task_description = "Label E-commerce products as their product types given their product description."
optimus_prime = OptimusPrompt(
    task_description=task_description,
    initial_instruction=initial_instruction,
    meta_client=meta_client,
    meta_generation_config=meta_generation_config,
    num_mutation_variations=10,
    num_refine_variations=5
)

def eval_func(instruction):
    ca.instructions = instruction
    return ca.evaluate_accuracy(X=df_test['text'], y_true=df_test['label'])

X = df_test['text'].to_list()
y_true = df_test['label'].to_list()

# score cached instructions
optimus_prime.score_cache(eval_func=eval_func)

# select best instructions
best_instruction = optimus_prime.select_top_k_instructions(k=1)[0]

num_rounds = 1
for i in tqdm(range(num_rounds)):
    logger.info(f"Round {i+1}")
    
    # mutate best instruction
    mutations = optimus_prime.mutate(seed_instruction=best_instruction)
    optimus_prime.instruction_cache += mutations
    logger.info(f"Mutations completed for {len(mutations)} instructions")

    # critique best instruction
    y_pred = ca.run_samples(X)
    wrong_examples = []
    for i in range(len(y_pred)):
        if y_pred[i] != y_true[i]:
            wrong_examples.append((X[i], y_true[i], y_pred[i]))
    logger.info(f"Found {len(wrong_examples)} wrong examples")

    wrong_example_text = optimus_prime.build_wrong_example_text(wrong_examples)
    critique = optimus_prime.critique(wrong_example_text=wrong_example_text, seed_instruction=best_instruction)
    wrong_example_with_critique = optimus_prime.build_wrong_example_with_critique_text(wrong_examples, critique)
    logger.info('Critique completed')

    # refine best instruction
    refined_instructions = optimus_prime.refine(seed_instruction=best_instruction, wrong_examples_with_critique=wrong_example_with_critique)
    logger.info('Refine completed')

    # add refined instructions to instruction cache
    optimus_prime.instruction_cache += refined_instructions

    # score cached instructions
    logger.info('Scoring cached instructions')
    optimus_prime.score_cache(eval_func=eval_func)

    # select best instructions
    best_instruction = optimus_prime.select_top_k_instructions(k=1)[0]

system_message = optimus_prime.get_expert(seed_instruction=best_instruction)

print(system_message)
print(best_instruction)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2025-02-06 14:56:39,095 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:39,468 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:39,847 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:40,721 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:41,105 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:41,469 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:41,850 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:42,218 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:42,579 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:43,178 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:43,550 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:43,997 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:44,382 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:44,819 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:45,711 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:46,082 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:46,458 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:46,842 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:52,303 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:52,673 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:53,114 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:53,514 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:53,898 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:54,545 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:54,928 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:55,375 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:55,780 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:56,193 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:56,562 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:57,011 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:57,378 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:57,828 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:58,240 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:56:58,596 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:00,494 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:00,869 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:01,252 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:01,629 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:01,988 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:02,228 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 502 Bad Gateway"
# 2025-02-06 14:57:02,238 - openai._base_client - INFO - Retrying request to /chat/completions in 0.429789 seconds
# 2025-02-06 14:57:03,008 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:03,463 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:03,828 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:04,277 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:04,642 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:05,102 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:05,478 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:05,921 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:06,355 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:06,842 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:07,224 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:07,593 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:08,175 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:08,580 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:08,957 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:09,326 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:09,690 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:10,059 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:11,041 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:11,409 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:11,856 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:12,224 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:12,592 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:12,989 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:13,384 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:13,811 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:14,174 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:14,625 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:15,028 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:15,410 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:15,807 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:16,194 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:16,573 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:16,956 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:17,346 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:17,798 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:18,176 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:18,554 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:18,927 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:19,308 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:19,690 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:20,156 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:20,553 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:20,942 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:21,384 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:22,303 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:22,708 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:23,076 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:23,441 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:23,829 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:24,239 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:24,640 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:25,030 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:25,466 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:25,902 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:26,287 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:26,720 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:27,113 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:27,527 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:27,923 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:28,298 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-02-06 14:57:28,358 - my_app - INFO - Round 1
# Instructions:
# Given a task description and a seed task instruction used for an agent to complete a task, you are to generate diverse variations of the seed task instruction by applying various thinking styles.
#
# [Task Description]: Label E-commerce products as their product types given their product description.
# [Seed Task Instruction]: Based on the given input item description, label the item as one of the following: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].
#
# Steps:
# - Analyze the task description and the seed task instruction. Think about how the seed task instruction accomplishes the task described.
# - Consider the following thinking styles and apply them to the seed task instruction. For each thinking style, thinking about how the seed task instruction may be improved by applying the thinking style.
# - Generate 10 mutated instructions from the seed task instruction by applying each thinking styles.
# - You may dynamically mix thinking styles to create more diverse variations.
# - You must generate mutated instructions that keep similar semantic meaning as the original seed task instruction.
# - You must generate mutated instructions that can be used to instruct an agent to accomplish the task described in the task description.
#
# [Thinking Styles]:
# - Does the problem involve decision-making or planning, where choices need to be made under uncertainty or with competing objectives?
# - Given the problem specification and the current best solution, have a guess about other possible solutions.
# - Are there any potential solutions or strategies that have been tried before? If yes, what were the outcomes and lessons learned?
# - What is the core issue or problem that needs to be addressed?
# - Ignoring the current best solution, create an entirely new solution to the problem.
# - Are there any relevant data or information that can provide insights into the problem? If yes, what data sources are available, and how can they be analyzed?
# - What are the underlying causes or factors contributing to the problem?
# - What are the potential obstacles or challenges that might arise in solving this problem?
# - What is the best way to modify this current best solution, given what you know about these kinds of problem specification?
# - How could I measure progress on this problem?
#
# -----------------------------------------
# Output Format:
# Return your output in a json format with the following fields. Do not return anything except the json object.
# - thinking: (str) Return logical reasoning for the mutation as well as the steps you took to arrive at the mutation.
# - mutated_instructions: (list) Return a list of the variations of the seed instruction that you generated.
# 2025-02-06 14:57:39,918 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:39,921 - my_app - INFO - Mutations completed for 10 instructions
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2025-02-06 14:57:41,031 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:41,387 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:41,864 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:42,234 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:42,615 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:42,984 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:43,398 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:43,912 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:44,317 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:44,712 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:45,085 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:46,063 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:46,472 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:46,830 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:47,285 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:47,906 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:48,296 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:48,685 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:49,131 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:49,500 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:49,882 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:50,247 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:50,621 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:51,079 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:51,489 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:51,862 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:52,298 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:52,668 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:53,130 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:53,742 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:55,073 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:55,442 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:55,817 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:56,173 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:56,544 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:56,904 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:57,274 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:57,733 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:58,097 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:58,467 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:58,837 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:59,274 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:57:59,624 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:00,090 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:00,460 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:00,910 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:01,823 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:02,549 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:02,922 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:03,358 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:03,778 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:04,139 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:04,597 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:04,972 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:05,340 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:05,825 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:06,196 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:06,645 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:07,000 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:07,460 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:07,821 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:08,273 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:08,664 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:09,049 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:09,421 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:09,820 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:10,189 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:10,569 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:10,954 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:11,457 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:11,825 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:12,236 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:12,693 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:13,246 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:13,622 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:14,007 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:14,395 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:14,836 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:15,196 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:15,614 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:16,004 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:16,420 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:16,884 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:17,294 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:17,708 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:18,417 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:18,800 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:19,124 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 502 Bad Gateway"
# 2025-02-06 14:58:19,138 - openai._base_client - INFO - Retrying request to /chat/completions in 0.438915 seconds
# 2025-02-06 14:58:19,917 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:20,368 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:20,767 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:21,172 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:22,517 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:22,903 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:23,338 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:23,796 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:24,148 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:24,500 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:24,899 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:25,382 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:25,792 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:58:25,807 - my_app - INFO - Found 21 wrong examples
# 2025-02-06 14:58:46,474 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# LLM thinking: The current instruction does not provide enough context or guidance for the agent to correctly identify the product type based on the description. The agent seems to struggle with distinguishing between products that could be classified into multiple categories or those that are not clearly defined within the given options. The instruction should be refined to include specific keywords or phrases that are indicative of each product type, and possibly a hierarchy or set of rules to follow when the description hints at multiple categories.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 43
#      41 wrong_example_text = optimus_prime.build_wrong_example_text(wrong_examples)
#      42 critique = optimus_prime.critique(wrong_example_text=wrong_example_text, seed_instruction=best_instruction)
# ---> 43 wrong_example_with_critique = optimus_prime.build_wrong_example_with_critique_text(wrong_examples, critique)
#      44 logger.info('Critique completed')
#      46 # refine best instruction
#
# Cell In[7], line 79, in OptimusPrompt.build_wrong_example_with_critique_text(self, wrong_examples, critique)
#      72 wrong_examples_with_critique = []
#      73 for i in range(len(wrong_examples)):
#      75     wrong_examples_with_critique.append(f"""
#      76         [Text]:               {wrong_examples[i][0]}
#      77         [Correct Label]:      {wrong_examples[i][1]}
#      78         [Predicted Label]:    {wrong_examples[i][2]}
# ---> 79         [Critique]:           {critique[i]}""")
#      80 return "\n".join(wrong_examples_with_critique)
#
# IndexError: list index out of range

# %%
critique
# Out:
# ["The instruction fails to consider that skateboards are part of sports equipment and not electronics or household items. The agent might have been misled by the mention of 'carbon ball-bearings'. The instruction should include sports equipment as a separate category or at least mention skateboards under the 'Household' or 'Electronics' categories to avoid confusion.",
#  "The agent mislabels the cleaning air blower brush as 'Household' instead of 'Electronics'. The description does not clearly differentiate between these two categories. The instruction should be improved to include more specific keywords that are typically associated with electronics (e.g., 'battery-powered', 'electrical components', 'digital', etc.) and household items (e.g., 'cleaning supplies', 'kitchenware', 'furniture', etc.).",
#  "The agent incorrectly labels a piece of jewelry as 'Household'. The description of the pendant includes words that might be associated with household items if the context is not clear, such as 'long chain'. The instruction should clarify that jewelry falls under 'Clothing & Accessories' and not 'Household'.",
#  "The agent mislabels a book about Alibaba as 'Household'. The description includes many keywords that might be misleading, such as 'Alibaba' and 'rise', which are not specific enough to clearly identify the product as a book. The instruction should include more specific indicators for books, such as mentioning 'author', 'publisher', 'review', and 'product description'.",
#  "The agent labels a Blu-ray disc as 'Books'. This is likely due to the text-heavy description typical of book product descriptions. The instruction should be more specific in identifying electronic media like Blu-rays, possibly by adding 'media players', 'audio/visual equipment', or 'digital media' to the 'Electronics' category.",
#  "The agent labels a book about food production operations as 'Household'. The text includes terms like 'Food Production Operations' which might be associated with household items. The instruction should clarify that educational and technical books belong to the 'Books' category and provide a way to distinguish them from household items.",
#  "The agent labels speakers as 'Household' instead of 'Electronics'. This could be due to the description's mention of 'home' and 'kitchen'. The instruction should be more explicit about identifying audio equipment under 'Electronics'.",
#  "The agent labels a board game as 'Books'. The description includes the phrase 'board game' which might not be clearly categorized. The instruction should specify that games and educational materials are part of 'Books' unless they clearly indicate they are electronic or household items.",
#  "The agent labels a folding hand truck as 'Books'. This is likely due to the text-heavy nature of the description. The instruction should clarify that items primarily used for transportation or carrying goods are 'Household' items.",
#  "The agent labels a tactical rod as 'Electronics'. This product is clearly a household item or a tool, but the description might not have provided enough context. The instruction should include specific keywords or phrases that clearly define 'Household' items and differentiate them from 'Electronics'.",
#  "The agent labels a pack of beads for DIY jewelry as 'Clothing & Accessories'. This is likely due to the mention of 'jewelry making'. The instruction should clarify that craft supplies belong to 'Household' unless they are specifically wearable accessories.",
#  "The agent labels an inverter battery as 'Electronics'. While this could be argued, the primary use of such a product is typically in household electrical systems. The instruction should clarify that batteries for home use are categorized under 'Household'.",
#  "The agent labels a romper as 'Household'. This is a clear misclassification due to the description's mention of 'extra soft' and 'warm', which might have led the agent to consider it as a household item. The instruction should include specific keywords related to clothing and accessories.",
#  "The agent labels a wall TV unit as 'Household'. While this could be considered household furniture, the description includes terms like 'TV unit', which might be misleading. The instruction should clarify that electronic accessories and mounts are categorized under 'Electronics'.",
#  "The agent labels a digital photo frame as 'Household'. This is a clear misclassification since a photo frame with a digital display is an electronic device. The instruction should include specific keywords for electronic devices that display media."]

# %%
len(wrong_examples)
# Out:
# 21

# %%
print("Final Evaluation")
ca.instructions = best_instruction
ca.system_message = system_message
print(f"Accuracy = {ca.evaluate_accuracy(X=X, y_true=y_true)}")
# Out:
# Final Evaluation
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-02-06 14:51:23,122 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nPigeon Popcorn Maker, 1200watts, Yellow No movie marathon is complete without a bowl of popcorn. Bring home the Pigeon Popcorn Maker and make delicious and fresh popcorn easily.\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:23,128 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:23,131 - httpcore.connection - DEBUG - close.started
# 2025-02-06 14:51:23,133 - httpcore.connection - DEBUG - close.complete
# 2025-02-06 14:51:23,139 - httpcore.connection - DEBUG - connect_tcp.started host='api.studio.nebius.ai' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-02-06 14:51:23,392 - httpcore.connection - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000204746A4170>
# 2025-02-06 14:51:23,394 - httpcore.connection - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x0000020474304950> server_hostname='api.studio.nebius.ai' timeout=5.0
# 2025-02-06 14:51:23,605 - httpcore.connection - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000020475A18EF0>
# 2025-02-06 14:51:23,607 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:23,613 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:23,618 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:23,622 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:23,624 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:23,952 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:23 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'560'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:23,958 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:23,964 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:23,964 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:23,973 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:23,979 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:23,986 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:23 GMT', 'content-type': 'application/json', 'content-length': '560', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:23,991 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:24,034 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nboAt BassHeads 225 in-Ear Super Extra Bass Headphones (Black) Colour:Black   boAt BassHeads 225 polished metal earphones are designed to give you an experience which no other brand can match. It has an incredible sonic clarity with "Super Extra Bass". It is not a plastic earphone - It is polished metal. With tangle free flat cables, you are expected to be hassle free. As the headphones feature 10mm drivers, they give you clear sound with that thumping bass. In-built noise cancelling mic ensures you don\'t miss those important calls. With colors that match your style in your day, the boAt earphones are the ideal choice for anyone who can carry that attitude. Just plug them in and plug into nirvana. boAt contact_us on : [ 02242102403 ]\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:24,044 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:24,051 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,058 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:24,065 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,072 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:24,075 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,408 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:23 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'562'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:24,408 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:24,415 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,419 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:24,427 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:24,427 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:24,436 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:23 GMT', 'content-type': 'application/json', 'content-length': '562', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:24,441 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:24,488 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nPrestige PIC 3.1 V3 2000-Watt Induction Cooktop with Touch Panel (Black) Style:PIC 3.1 V3 2000-Watt Induction Cooktop with Touch panel   The innovative Prestige Induction Cook-Top offers quick and consistent heating at highest efficiency. Add to this its anti-magnetic wall, soft touch buttons, durability, safety and elegance makes cooking a pleasing and enjoyable experience. The Prestige Induction Cook-Top comes with the unique whistle counter, power saver technology and keep warm function wherein the Induction Cook-Top dynamically monitors the temperature of the vessel and adjusts the power level based on the size (base diameter) of the vessel. The dual heat sensor provided in the Induction Cook-Top automatically senses the temperature of the vessel and prevents over heating thereby saving power. With latest technology and features, this cooktop will be the best addition to your kitchen!\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:24,494 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:24,501 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,506 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:24,511 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,519 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:24,525 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,855 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:24 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'562'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:24,857 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:24,857 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,869 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:24,874 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:24,877 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:24,882 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:24 GMT', 'content-type': 'application/json', 'content-length': '562', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:24,882 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:24,934 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nThink & Grow Rich - Lectures by Napoleon Hill [MP3]\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:24,942 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:24,947 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,951 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:24,959 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:24,963 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:24,972 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:25,289 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:24 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'556'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:25,289 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:25,289 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:25,302 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:25,305 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:25,306 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:25,309 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:24 GMT', 'content-type': 'application/json', 'content-length': '556', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:25,312 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:25,328 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nDeckUp Meritus-S Wall TV Unit (Dark Wenge, Matte Finish) Color:Dark Wenge   Assembly Required: The Product Requires Basic Assembly And Comes With Diy (Do-It-Yourself) Assembly Instructions.Product Dimensions: Length (30 Inches), Width (12 Inches), Height (11 Inches).Primary Material: Engineered Wood With Melamine Laminate.Color: Dark Wenge, Finish: Matte Finish, Style: Contemporary.\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:25,339 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:25,345 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:25,348 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:25,356 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:25,363 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:25,369 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:25,694 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:25 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'562'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:25,706 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:25,710 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:25,714 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:25,718 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:25,722 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:25,727 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:25 GMT', 'content-type': 'application/json', 'content-length': '562', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:25,729 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:25,782 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nBlack+Decker Hand Tool Kit (108-Piece), Orange and Black\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:25,792 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:25,798 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:25,806 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:25,808 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:25,818 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:25,827 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:26,156 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:25 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'560'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:26,160 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:26,160 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:26,170 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:26,174 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:26,180 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:26,187 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:25 GMT', 'content-type': 'application/json', 'content-length': '560', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:26,192 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:26,227 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nAlibaba: The House that Jack Ma Built Review “Anybody who thinks the Chinese just copy or steal technology from the West should read this book and think again. Jack Ma is part Bill Gates, part Steve Jobs, part Larry Page, part Sergei Brin, and part Mark Zuckerberg all rolled into one.” (Sir Martin Sorrell, CEO of WPP)“Useful, business-minded reporting on an unconventional corporate magnate, containing both corporate and human-interest perspectives.” (Kirkus Reviews)“This absorbing and well-written portrayal of Ma’s character, and his role in Alibaba’s development will appeal to a wide range of readers.” (Library Journal)“A clean and compelling narrative…[Clark] tells the story with flair.” (Wall Street Journal)“A fascinating new book.” (The Economist)“A must-read for anyone hoping to navigate China’s new economy”. (Financial Times) \t\t\t\t    \t \t\t\t\t\t From the Back Cover An engrossing, insider’s account of how a teacher built one of the world’s most valuable companies—rivaling Walmart and Amazon—and forever reshaped the global economyIn just a decade and a half, Jack Ma, a man from modest beginnings who started out as an English teacher, founded Alibaba and built it into one of the world’s largest companies, an e-commerce empire on which hundreds of millions of Chinese consumers depend. In 2014, Alibaba’s $25 billion IPO was the largest global IPO in history. A Rockefeller of his time, who is courted by CEOs and presidents around the world, Jack is an icon for China’s booming private sector and the gatekeeper to hundreds of millions of middle-class consumers. Duncan Clark first met Jack in 1999 in the small apartment where Jack founded Alibaba. Granted unprecedented access to a wealth of new material, including exclusive interviews, Clark draws on his own experience as an early adviser to Alibaba as well as his two decades in China chronicling the Internet’s impact on the country to create an authoritative, compelling narrative account of Alibaba’s rise.How did Jack overcome his humble origins and early failures to achieve massive success with Alibaba? How did he outsmart rival entrepreneurs from both China and Silicon Valley? Can Alibaba maintain its 80 percent market share? As it forges ahead into finance and entertainment, are there limits to Alibaba’s ambitions? How does the Chinese government view its rise? Will Alibaba expand ...
# 2025-02-06 14:51:26,237 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:26,241 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:26,247 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:26,251 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:26,257 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:26,264 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:26,608 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:25 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'558'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'399913'), (b'x-ratelimit-reset-tokens', b'1s'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:26,612 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:26,614 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:26,618 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:26,623 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:26,628 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:26,632 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:25 GMT', 'content-type': 'application/json', 'content-length': '558', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '399913', 'x-ratelimit-reset-tokens': '1s', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:26,643 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:26,679 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nBaby Boy/Girl Romper Newborn Jumpsuit Blue Hooded Romper Extra Soft Warm Woolen Material Baby Winter Clothes Newborn Baby Boy Girl Hooed Footed Romper Kids Long Sleeves Jumpsuit...Winter Romper to keep your baby warm and comfortable\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:26,687 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:26,695 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:26,704 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:26,709 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:26,713 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:26,719 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:27,281 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:26 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'574'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:27,286 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:27,290 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:27,292 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:27,296 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:27,301 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:27,305 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:26 GMT', 'content-type': 'application/json', 'content-length': '574', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:27,307 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:27,340 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nS4S Men\'s 100% Cotton Premium Collection Handkerchiefs - Pack of 12 (White_46X46 CM) An ideal handkerchief for modern gentleman from our premium collection. These 100% premium cotton formal handkerchiefs are soft and gentle on skin and absorb sweat keeping you fresh and feeling refreshed. Feel the softness after 2-3 wash. Made from 100% cotton fabric, Large in size. These handkerchiefs are perfect accessory to complement your look.\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:27,375 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:27,392 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:27,400 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:27,408 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:27,412 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:27,420 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:27,793 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:27 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'574'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:27,797 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:27,800 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:27,806 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:27,811 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:27,811 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:27,817 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:27 GMT', 'content-type': 'application/json', 'content-length': '574', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:27,821 - openai._base_client - DEBUG - request_id: None
# 2025-02-06 14:51:27,855 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an information scientist with a specialization in data analysis and categorization, particularly within the domains of retail and library science. Your expertise lies in parsing and analyzing text for keywords and accurately categorizing items based on their descriptions. You have extensive experience in identifying and organizing items into predefined categories such as 'Household', 'Books', 'Clothing & Accessories', and 'Electronics'. Your skills are highly valuable in ensuring that items are correctly labeled, making it easier for users to find what they are looking for. You are adept at using sophisticated analytical tools and your deep understanding of each category allows you to make informed decisions about how to best classify items."}, {'role': 'user', 'content': 'Instructions:\n["List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\']."]\n\nReturn your output in a json object with the following fields according to the format below. You must not return anything else besides the json object.\n\n----------------\nOutput format:\nlabel: (Literal) Return one of the choices from the following list: [\'Household\', \'Books\', \'Clothing & Accessories\', \'Electronics\'].\n----------------\nInput:\nKraft Seeds Multipurpose Kitchen Household and Garden Scissor (Color May Vary) Sharp edges easy to use confortable grip stylish look. Total length: 8.5-inch, blade size: 4.5-inch.\n'}, {'role': 'assistant', 'content': '{"label": '}], 'model': 'meta-llama/Llama-3.2-3B-Instruct', 'temperature': 1e-10, 'top_p': 1e-10}, 'extra_json': {'guided_json': {'properties': {'label': {'title': 'Label', 'type': 'string'}}, 'required': ['label'], 'title': 'classifier_schema', 'type': 'object'}}}
# 2025-02-06 14:51:27,869 - openai._base_client - DEBUG - Sending HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions
# 2025-02-06 14:51:27,872 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:27,881 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-02-06 14:51:27,889 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:27,895 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-02-06 14:51:27,899 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-02-06 14:51:28,306 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 06 Feb 2025 06:51:27 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'560'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'600'), (b'x-ratelimit-limit-tokens', b'400000'), (b'x-ratelimit-remaining-requests', b'600'), (b'x-ratelimit-remaining-tokens', b'400000'), (b'Strict-Transport-Security', b'max-age=15724800; includeSubDomains')])
# 2025-02-06 14:51:28,308 - httpx - INFO - HTTP Request: POST https://api.studio.nebius.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-06 14:51:28,315 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-02-06 14:51:28,318 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-02-06 14:51:28,327 - httpcore.http11 - DEBUG - response_closed.started
# 2025-02-06 14:51:28,329 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-02-06 14:51:28,335 - openai._base_client - DEBUG - HTTP Response: POST https://api.studio.nebius.ai/v1/chat/completions "200 OK" Headers({'date': 'Thu, 06 Feb 2025 06:51:27 GMT', 'content-type': 'application/json', 'content-length': '560', 'connection': 'keep-alive', 'x-ratelimit-limit-requests': '600', 'x-ratelimit-limit-tokens': '400000', 'x-ratelimit-remaining-requests': '600', 'x-ratelimit-remaining-tokens': '400000', 'strict-transport-security': 'max-age=15724800; includeSubDomains'})
# 2025-02-06 14:51:28,341 - openai._base_client - DEBUG - request_id: None
# Accuracy = 0.9

# %%
optimus_prime.instruction_population
# Out:
# [("List of ideas: Consider the following steps: analyze the text for keywords, compare the description with known items in each category, and then label the item as one of the following: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.9),
#  ("Label the item based on the product description: ['Household', 'Books', 'Clothing & Accessories', 'Electronics']. Items designed for babies and children, especially those with descriptors like 'Romper' and 'Jumpsuit', should be labeled as 'Clothing & Accessories'.",
#   0.9),
#  ("Determine the category of the item from the description: ['Household', 'Books', 'Clothing & Accessories', 'Electronics']. Items that hold or support electronic devices like TVs should be labeled under 'Electronics'.",
#   0.9),
#  ("Step-by-step approach: First, read the item description carefully. Then, identify key words or phrases that suggest the product type. Finally, label the item as one of the following: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.8),
#  ("Best way to improve: Instead of labeling directly, first classify the description's primary focus. Then, match it with one of these categories: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.8),
#  ("Decision-making under uncertainty: If unsure, use a process of elimination based on the description's content. Label the item as one of the following: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'], selecting the category with the highest probability of accuracy.",
#   0.8),
#  ("Classify the item into one of these categories: ['Household', 'Books', 'Clothing & Accessories', 'Electronics']. If the description includes reviews, literary acclaim, and quotes, label it as 'Books'.",
#   0.8),
#  ("Simplify the problem: Focus on the most distinctive features in the description to determine if the item belongs to one of these categories: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.7),
#  ("Alternative solutions: Try matching the description against a database of known product types or use a machine learning model trained on similar product descriptions to label the item as one of the following: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.7),
#  ("Key assumptions: Assume the item description is accurate and contains enough information to categorize it under one of these types: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.7),
#  ("Risks and drawbacks: Be aware that the item description might be ambiguous or contain multiple categories. Label the item as one of the following: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'], choosing the most fitting category.",
#   0.7),
#  ("Identify the item type from the description: ['Household', 'Books', 'Clothing & Accessories', 'Electronics']. Items related to kitchen appliances and daily home use should be labeled as 'Household'.",
#   0.7),
#  ("Based on the given input item description, label the item as one of the following: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.6),
#  ("Risk analysis: Before labeling the item, consider the risk of misclassification. Ensure the description aligns closely with one of these categories: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.6),
#  ("Physical constraints: If the description mentions size or physical dimensions, consider how this might limit the product to a specific category. Label the item accordingly from these options: ['Household', 'Books', 'Clothing & Accessories', 'Electronics'].",
#   0.6),
#  ("Based on the given input item description, label the item as one of the following: ['Household', 'Books', 'Clothing & Accessories', 'Electronics']. Focus on the overall context rather than isolated keywords.",
#   0.6)]
